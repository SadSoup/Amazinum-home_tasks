# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\redmi\anaconda3\envs\py310\lib\site-packages (6.1.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\redmi\anaconda3\envs\py310\lib\site-packages (from plotly) (1.40.0)
# Requirement already satisfied: packaging in c:\users\redmi\anaconda3\envs\py310\lib\site-packages (from plotly) (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
cic = pd.read_csv("Car_Insurance_Claim.csv")

# %%
import plotly.express as px

cic['CREDIT_SCORE'] = pd.to_numeric(cic['CREDIT_SCORE'], errors='coerce')
fig = px.box(cic['CREDIT_SCORE'], y="CREDIT_SCORE")
fig.show()
